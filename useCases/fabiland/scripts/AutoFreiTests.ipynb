# %%
import pandas as pd

# %%
base = pd.read_csv("/home/brendan/git/silo/useCases/fabiland/scenario/scenOutput/base/avgSatisfactionByZone_base.csv")
policy = pd.read_csv("/home/brendan/git/silo/useCases/fabiland/scenario/scenOutput/base/avgSatisfactionByZone_policy.csv")

# %%
policy.head()
# Out:
#   zone      avgSatisfaction              avgProp year
# 0    1  0.12280260233844255  0.08719006839701185    1
# 1    2  0.08515294864097894  0.14104434132920057    1
# 2    3   0.2650501217684014   0.0913587355063226    1
# 3    4   0.2448101344060386  0.07201396410230788    1
# 4    5  0.09848246455445277  0.09321934310869487    1

# %%
base_13_S = base[base["zone"] == "13"]
base_13_S["avgSatisfaction"] = pd.to_numeric(base_13_S["avgSatisfaction"], errors="coerce")
# base_13_S["avgSatisfaction"].mean()

base_13_P = base[base["zone"] == "13"]
base_13_P["avgProp"] = pd.to_numeric(base_13_P["avgProp"], errors="coerce")
# base_13_P["avgProp"].mean()

print("zone 13 base Satisfaction: ", base_13_S["avgSatisfaction"].mean())
print("zone 13 base Prop to move: ", base_13_S["avgProp"].mean())
# Out:
# zone 13 base Satisfaction:  0.19873045559881253
# zone 13 base Prop to move:  0.08308358488306133
# /tmp/ipykernel_88934/2214987494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_13_S["avgSatisfaction"] = pd.to_numeric(base_13_S["avgSatisfaction"], errors="coerce")
# /tmp/ipykernel_88934/2214987494.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_13_P["avgProp"] = pd.to_numeric(base_13_P["avgProp"], errors="coerce")

# %%
base["avgSatisfaction"] = pd.to_numeric(base["avgSatisfaction"], errors="coerce")
base_S_allzones = base["avgSatisfaction"]
# base_S_allzones.mean()


base["avgProp"] = pd.to_numeric(base["avgProp"], errors="coerce")
base_P_allzones = base["avgProp"]
# base_P_allzones.mean()

# base_allzones[base_allzones["avgSatisfaction"]].mean()

# %%
print(base_13_S["avgSatisfaction"].mean() / base_S_allzones.mean())

print(base_13_P["avgProp"].mean() / base_P_allzones.mean())
# Out:
# 0.9172196139377837
# 0.8135163248642484

# %%
policy_13_S = policy[policy["zone"] == "13"]
policy_13_S["avgSatisfaction"] = pd.to_numeric(policy_13_S["avgSatisfaction"], errors="coerce")
# policy_13_S["avgSatisfaction"].mean()

policy_13_P = policy[policy["zone"] == "13"]
policy_13_P["avgProp"] = pd.to_numeric(policy_13_P["avgProp"], errors="coerce")
# policy_13_P["avgProp"].mean()

print("zone 13 policy  Satisfaction: ", policy_13_S["avgSatisfaction"].mean())
print("zone 13 policy Prop to move: ", policy_13_S["avgProp"].mean())
# Out:
# zone 13 policy  Satisfaction:  0.1570603020779263
# zone 13 policy Prop to move:  0.08525122821083374
# /tmp/ipykernel_88934/2745029612.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   policy_13_S["avgSatisfaction"] = pd.to_numeric(policy_13_S["avgSatisfaction"], errors="coerce")
# /tmp/ipykernel_88934/2745029612.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   policy_13_P["avgProp"] = pd.to_numeric(policy_13_P["avgProp"], errors="coerce")

# %%
policy["avgSatisfaction"] = pd.to_numeric(policy["avgSatisfaction"], errors="coerce")
policy_S_allzones = policy["avgSatisfaction"]
# policy_S_allzones.mean()

policy["avgProp"] = pd.to_numeric(policy["avgProp"], errors="coerce")
policy_P_allzones = policy["avgProp"]
# policy_P_allzones.mean()

# %%
print(policy_13_S["avgSatisfaction"].mean() / policy_S_allzones.mean())
print(policy_13_P["avgProp"].mean() / policy_P_allzones.mean())
# Out:
# 0.7620574214414428
# 0.892060397948594
